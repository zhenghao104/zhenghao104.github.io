# %%
import pandas as pd

# %% [markdown]
# 1. total sales for each day of the week

# %%
dailyDf = pd.read_csv("daily_sales.csv")
monthlyDf = pd.read_csv("monthly_sales.csv")

# %%
dailyDf.index = dailyDf['Unnamed: 0']
dailyDf = dailyDf.drop("Unnamed: 0", axis=1)
dailyDf = dailyDf.rename_axis('Week')

# %%
dailyDf
# Out:
#                  Day  HM-NE  CF-NE  FF-NE  HM-SW  CF-SW  FF-SW  HM-NW  CF-NW  \
# Week
# Friday      1/1/2016  37240  16077   8446  39249  16565  10204  37271  16819
# Saturday    1/2/2016  36258  14726   7950  38106  14003   7316  35021  14705
# Sunday      1/3/2016  37007  15103   8397  35494  15987   8683  35369  16591
# Monday      1/4/2016  37590  16413   9537  33666  15114   8429  37993  14535
# Tuesday     1/5/2016  38036  16199  10123  33528  13721  10085  37854  14590
# Wednesday   1/6/2016  38187  16386   8410  33608  14322   9652  36343  16302
# Thursday    1/7/2016  38095  16045  11791  33007  15068   8985  35901  15408
# Friday      1/8/2016  34685  15058   8179  38964  13608  10985  36279  14465
# Saturday    1/9/2016  35059  14585   7193  33637  14035   7616  38059  13804
# Sunday     1/10/2016  36906  16905  10580  39361  14788   7105  35332  15809
# Monday     1/11/2016  36893  16771  10091  35750  16565   9506  37802  15222
# ...

# %%
dailyDfFiltered = dailyDf.drop("Day",axis=1).groupby("Week").mean()
dailyDfFiltered = dailyDfFiltered.reindex(['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'])

# %%
str(list(dailyDfFiltered.mean(axis=1)))
# Out:
# '[19771.626666666667, 20210.916666666668, 20001.55, 20263.966666666667, 20248.65, 20705.8, 19622.22666666667]'

# %%
str(list(dailyDfFiltered[region_NE].sum(axis=1)))
# Out:
# '[63375.2, 62547.0, 62738.5, 62629.25, 64903.0, 59813.99999999999, 58755.59999999999]'

# %%
list(dailyDfFiltered[region_SW].index)
# Out:
# ['Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday', 'Wednesday']

# %%
dailyDfFiltered_group = dailyDfFiltered.groupby("Week").mean()
dailyDfFiltered_group = dailyDfFiltered_group.reindex(['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'])
str(list(dailyDfFiltered_group.sum(axis=1)))
# Out:
# '[296574.4, 303163.75, 300023.25, 303959.5, 303729.75, 310587.0, 294333.4]'

# %%
df_month_group_pie= monthlyDf.drop("Month",axis=1).groupby("Month_short").mean()
df_month_group_pie = df_month_group_pie.reindex(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
str(list(df_month_group_pie.sum(axis=1)))

# %%
monthlyDf
# Out:
#      Month    HM-NE   CF-NE   FF-NE    HM-SW   CF-SW   FF-SW    HM-NW   CF-NW  \
# 0   Jan-16  1140955  494802  285238  1124565  468568  281141  1111618  482079
# 1   Feb-16  1175529  489804  293882  1200559  480616  288369  1188037  475603
# 2   Mar-16  1235995  494802  296881  1220454  508522  293148  1151657  499443
# 3   Apr-16  1186592  514593  296648  1213616  485843  291505  1149180  498369
# 4   May-16  1272450  530187  305637  1249686  520702  312421  1187579  494824
# 5   Jun-16  1235025  535597  321358  1213908  505795  303477  1239785  496319
# 6   Jul-16  1284426  535177  321106  1269486  508209  317371  1202069  500862
# 7   Aug-16  1323348  551395  330837  1358134  565889  326218  1283993  534997
# 8   Sep-16  1284426  535177  334213  1268860  528691  330162  1295077  518454
# 9   Oct-16  1280303  555233  333140  1315120  526477  328780  1301675  521095
# 10  Nov-16  1319100  572058  343235  1348519  561883  337129  1276693  553667
# ...

# %%
df_month_group_pie= monthlyDf.drop("Month",axis=1).groupby("Month_short").mean()
df_month_group_pie = df_month_group_pie.reindex(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
str(list(df_month_group_pie.sum(axis=1)))
# Out:
# '[11537605.5, 11783336.5, 11503497.5, 11653009.0, 12023085.75, 11647872.75, 11671713.5, 12234701.5, 12016076.0, 11319165.999999998, 11911040.999999998, 11624733.0]'

# %%
monthlyDf.groupby("Month_short").mean().sum(axis=1)
# Out:
# Month_short
# Apr    11653009.00
# Aug    12234701.50
# Dec    11624733.00
# Feb    11783336.50
# Jan    11537605.50
# Jul    11671713.50
# Jun    11647872.75
# Mar    11503497.50
# May    12023085.75
# Nov    11911041.00
# Oct    11319166.00
# Sep    12016076.00
# dtype: float64

# %%
monthlyDf.index = monthlyDf['Month, Year']
monthlyDf = monthlyDf.drop("Month, Year", axis=1)
monthlyDf = monthlyDf.rename_axis('Month')

# %%
monthlyDf = monthlyDf.reset_index()
monthlyDf['Month_short'] = [i.split('-')[0] for i in monthlyDf.reset_index()['Month']]

# %%
df_month_group= monthlyDf.drop("Month",axis=1).groupby("Month_short").mean()
df_month_group = df_month_group.reindex(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
str(list(df_month_group[region_SE].mean(axis=1)))
# str(list(df_month_group.index))
str(list(df_month_group.index))
# Out:
# "['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']"

# %%
monthlyDf.sum(axis=0)
# Out:
# Month, Year    Jan-16Feb-16Mar-16Apr-16May-16Jun-16Jul-16Aug-...
# HM-NE                                                   65362334
# CF-NE                                                   27233220
# FF-NE                                                   16345942
# HM-SW                                                   64421707
# CF-SW                                                   26815953
# FF-SW                                                   16104137
# HM-NW                                                   63572000
# CF-NW                                                   26341429
# FF-NW                                                   15821178
# HM-SE                                                   62328614
# CF-SE                                                   26039450
# FF-SE                                                   15614539
# HM-C                                                    61582375
# ...

# %%
# Index of monthly sales
list(monthlyDf.index)
# Out:
# ['Jan-16',
#  'Feb-16',
#  'Mar-16',
#  'Apr-16',
#  'May-16',
#  'Jun-16',
#  'Jul-16',
#  'Aug-16',
#  'Sep-16',
#  'Oct-16',
#  'Nov-16',
#  'Dec-16',
#  'Jan-17',
#  'Feb-17',
#  'Mar-17',
#  'Apr-17',
#  'May-17',
#  'Jun-17',
#  'Jul-17',
#  'Aug-17',
#  'Sep-17',
#  'Oct-17',
#  'Nov-17',
#  'Dec-17',
#  'Jan-18',
#  'Feb-18',
#  'Mar-18',
#  'Apr-18',
#  'May-18',
#  'Jun-18',
#  'Jul-18',
#  'Aug-18',
#  'Sep-18',
#  'Oct-18',
#  'Nov-18',
#  'Dec-18',
#  'Jan-19',
#  'Feb-19',
#  'Mar-19',
#  'Apr-19',
#  'May-19',
#  'Jun-19',
#  'Jul-19',
#  'Aug-19',
#  'Sep-19']

# %%
# pd.DataFrame(index=monthlyDf['Month, Year'], data= list(monthlyDf.sum(axis=1)),columns=['sum of sales'])

# Get all the relevant index from the dataframe
region_NE = monthlyDf.columns[monthlyDf.columns.str.contains("NE")]
region_SW = monthlyDf.columns[monthlyDf.columns.str.contains("SW")]
region_NW = monthlyDf.columns[monthlyDf.columns.str.contains("NW")]
region_SE = monthlyDf.columns[monthlyDf.columns.str.contains("SE")]
region_C = monthlyDf.columns[monthlyDf.columns.str.contains("-C")]
food_HM = monthlyDf.columns[monthlyDf.columns.str.contains("HM")]
food_CF = monthlyDf.columns[monthlyDf.columns.str.contains("CF")]
food_FF = monthlyDf.columns[monthlyDf.columns.str.contains("FF")]

# %%
str(list(monthlyDf[food_HM]['HM-C']))
# Out:
# '[1126476, 1109076, 1167894, 1116560, 1155612, 1149673, 1220954, 1252825, 1255322, 1213425, 1288024, 1199842, 1290590, 1386331, 1307257, 1335282, 1381392, 1344775, 1318052, 1431076, 1450080, 1374453, 1475555, 1517969, 1547730, 1517826, 1486792, 1532852, 1580994, 1474712, 1583461, 1543848, 1520076, 1364454, 1451913, 1360520, 1434785, 1416053, 1375864, 1448080, 1500448, 1407434, 1366136, 1416674, 1383228]'

# %%
str(list(monthlyDf[region_C].sum(axis=1)))
# Out:
# '[1859053, 1859777, 1935039, 1872326, 1937812, 1927852, 2034922, 2122132, 2071691, 2055393, 2125660, 1999736, 2164151, 2287898, 2214332, 2225469, 2279748, 2277884, 2210202, 2424068, 2402583, 2304779, 2435147, 2529948, 2564375, 2545197, 2453692, 2554753, 2678010, 2497981, 2639101, 2599335, 2559311, 2251794, 2419854, 2267533, 2391308, 2398621, 2316506, 2413466, 2486036, 2322725, 2254571, 2347234, 2328904]'
